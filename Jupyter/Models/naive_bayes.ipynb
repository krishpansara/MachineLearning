# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("E:/COADING/MachineLearning/DataSet/play_tennis.csv")
df = df.drop(columns=['day'])
df
# Out:
#      outlook  temp humidity    wind play
# 0      Sunny   Hot     High    Weak   No
# 1      Sunny   Hot     High  Strong   No
# 2   Overcast   Hot     High    Weak  Yes
# 3       Rain  Mild     High    Weak  Yes
# 4       Rain  Cool   Normal    Weak  Yes
# 5       Rain  Cool   Normal  Strong   No
# 6   Overcast  Cool   Normal  Strong  Yes
# 7      Sunny  Mild     High    Weak   No
# 8      Sunny  Cool   Normal    Weak  Yes
# 9       Rain  Mild   Normal    Weak  Yes
# 10     Sunny  Mild   Normal  Strong  Yes
# 11  Overcast  Mild     High  Strong  Yes
# 12  Overcast   Hot   Normal    Weak  Yes
# 13      Rain  Mild     High  Strong   No

# %% [markdown]
# # Intution

# %%
# Problem 1

# Outlook = Sunny, Temp = Hot, Humidity	= High, Wind = Weak
# Play or no?

# %%
# Solution

# P(Yes | Sunny,Hot,High,Weak) = P(Sunny|Yes) * P(Hot|Yes) * P(High|Yes) * P(Weak|Yes) * P(Yes)
# P(No | Sunny,Hot,High,Weak) = P(Sunny|No) * P(Hot|No) * P(High|No) * P(Weak|No) * P(No)

# Compare and decide according to Maximum A Posteriori rule

# %%
# Problem 2

# Outlook = Overcast, Temp = Cool, Humidity	= High, Wind = Weak
# Play or no?

# %%
# Solution

# P(Yes | Overcast, Cool, High, Weak) = P(Overcast|Yes) * P(Cool|Yes) * P(High|Yes) * P(Weak|Yes) * P(Yes)
# P(No | Overcast, Cool, High, Weak) = P(Overcast|No) * P(Cool|No) * P(High|No) * P(Weak|No) * P(No)

# Compare and decide according to Maximum A Posteriori rule

# %% [markdown]
# # Sklearn

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(500, 2, centers=3, random_state=2, cluster_std=1.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=32)

# %%
from sklearn.naive_bayes import GaussianNB

model_GNB = GaussianNB()
model_GNB.fit(X_train, y_train);

# %%
y_pred = model_GNB.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.91
