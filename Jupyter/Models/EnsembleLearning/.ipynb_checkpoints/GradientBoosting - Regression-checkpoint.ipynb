# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Intuition

# %%
df = pd.read_csv("E:/COADING/MachineLearning/DataSet/50_Startups.csv")
df = df.sample(3).drop("State", axis = 1)
df = round(df/1000)
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 32       63.0           129.0             46.0    97.0
# 15      115.0           123.0            262.0   130.0
# 6       135.0           147.0            128.0   156.0

# %%
df['f0(x)'] = df['Profit'].mean()
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit       f0(x)
# 32       63.0           129.0             46.0    97.0  127.666667
# 15      115.0           123.0            262.0   130.0  127.666667
# 6       135.0           147.0            128.0   156.0  127.666667

# %%
df['r_i1'] = df['Profit'] - df['f0(x)']
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit       f0(x)       r_i1
# 32       63.0           129.0             46.0    97.0  127.666667 -30.666667
# 15      115.0           123.0            262.0   130.0  127.666667   2.333333
# 6       135.0           147.0            128.0   156.0  127.666667  28.333333

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree

dt1 = DecisionTreeRegressor(max_depth=1)
dt1.fit(df.iloc[:,0:3].values, df['r_i1'].values)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 89.0\nsquared_error = 582.889\nsamples = 3\nvalue = -0.0'),
#  Text(0.25, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = -30.667'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'squared_error = 169.0\nsamples = 2\nvalue = 15.333'),
#  Text(0.625, 0.5, '  False')]

# %% [markdown]
# <b>Like this we have to go on further </b>
