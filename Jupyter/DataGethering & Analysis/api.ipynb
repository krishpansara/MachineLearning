# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
# df.head()

# %%
df = pd.DataFrame(temp_df)

# %%
df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6      155                                The Dark Knight
# 7    19404                    Dilwale Dulhania Le Jayenge
# 8      497                                 The Green Mile
# 9   496243                                       Parasite
# 10     680                                   Pulp Fiction
# 11     122  The Lord of the Rings: The Return of the King
# 12  372058                                     Your Name.
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# 15  157336                                   Interstellar
# 16     769                                     GoodFellas
# 17     346                                  Seven Samurai
# 18   12477                         Grave of the Fireflies
# 19     637                              Life Is Beautiful
#
#                                              overview release_date  \
# 0   Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   In the continuing saga of the Corleone crime f...   1974-12-20
# 3   The true story of how businessman Oskar Schind...   1993-12-15
# 4   The defense and the prosecution have rested an...   1957-04-10
# 5   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 6   Batman raises the stakes in his war on crime. ...   2008-07-16
# 7   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 8   A supernatural tale set on death row in a Sout...   1999-12-10
# 9   All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 10  A burger-loving hit man, his philosophical par...   1994-09-10
# 11  As armies mass for a final battle that will de...   2003-12-17
# 12  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 13  A man with a low IQ has accomplished great thi...   1994-06-23
# 14  While the Civil War rages on between the Union...   1966-12-22
# 15  The adventures of a group of explorers who mak...   2014-11-05
# 16  The true story of Henry Hill, a half-Irish, ha...   1990-09-12
# 17  A samurai answers a village's request for prot...   1954-04-26
# 18  In the final months of World War II, 14-year-o...   1988-04-16
# 19  A touching story of an Italian book seller of ...   1997-12-20
#
#     popularity  vote_average  vote_count
# 0      31.5995         8.711       28398
# 1      32.5244         8.686       21502
# 2      13.3161         8.570       12990
# 3      23.0253         8.600       16465
# 4      16.8272         8.548        9160
# 5      17.2311         8.536       17184
# 6      24.5010         8.520       33918
# 7       8.8818         8.517        4488
# 8      20.4195         8.505       18126
# 9      19.6701         8.499       19101
# 10     93.3917         8.489       28714
# 11     18.1770         8.485       25124
# 12     21.5580         8.500       11797
# 13     20.7370         8.468       28260
# 14     64.2492         8.500        9006
# 15     32.7217         8.455       37229
# 16     19.3463         8.455       13404
# 17     10.0390         8.500        3900
# 18      0.0109         8.449        5909
# 19     12.1514         8.448       13391

# %%
for i in range(1,50):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 7635     137             Groundhog Day
# 7636   42987               The Servant
# 7637  637649              Wrath of Man
# 7638   10331  Night of the Living Dead
# 7639    1933                The Others
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 7635  A narcissistic TV weatherman, along with his a...   1993-02-11
# 7636  Indolent aristocrat Tony employs competent Bar...   1963-11-14
# 7637  A cold and mysterious new security guard for a...   2021-04-22
# 7638  A group of strangers trapped in a farmhouse fi...   1968-10-04
# 7639  Grace is a religious woman who lives in an old...   2001-08-02
#
#       popularity  vote_average  vote_count
# 0        31.5995         8.711       28398
# 1        32.5244         8.686       21502
# 2        13.3161         8.570       12990
# 3        23.0253         8.600       16465
# 4        16.8272         8.548        9160
# ...          ...           ...         ...
# 7635      5.4971         7.615        8288
# 7636      2.7226         7.600         346
# 7637     13.1397         7.613        5597
# 7638      2.9536         7.613        2535
# 7639      6.6743         7.613        6707
#
# [7640 rows x 7 columns]

# %%
df.shape
# Out:
# (7640, 7)

# %%
df.to_csv('movies.csv')
