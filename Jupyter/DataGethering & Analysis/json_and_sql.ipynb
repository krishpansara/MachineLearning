# %%
import pandas as pd

# %% [markdown]
# # Woking with JSON

# %%
pd.read_json('E:/COADING/MachineLearning/DataSet/train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
import requests
# pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')

url = 'https://api.exchangerate-api.com/v4/latest/INR'
response = requests.get(url)
data = response.json()

df = pd.DataFrame.from_dict(data['rates'], orient='index', columns=['rate'])
df.index.name = 'currency'
df.reset_index(inplace=True)

df
# Out:
#     currency    rate
# 0        INR  1.0000
# 1        AED  0.0428
# 2        AFN  0.8090
# 3        ALL  1.0000
# 4        AMD  4.4700
# ..       ...     ...
# 158      XPF  1.2200
# 159      YER  2.8400
# 160      ZAR  0.2070
# 161      ZMW  0.3060
# 162      ZWL  0.0808
#
# [163 rows x 2 columns]

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# Out:
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      - -------------------------------------- 0.5/11.9 MB 1.3 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/11.9 MB 1.3 MB/s eta 0:00:09
#      -- ------------------------------------- 0.8/11.9 MB 1.0 MB/s eta 0:00:11
#      -- ------------------------------------- 0.8/11.9 MB 1.0 MB/s eta 0:00:11
#      --- ----------------------------------- 1.0/11.9 MB 853.0 kB/s eta 0:00:13
#      ----- --------------------------------- 1.6/11.9 MB 986.2 kB/s eta 0:00:11
#      ------ --------------------------------- 1.8/11.9 MB 1.0 MB/s eta 0:00:10
#      ------- -------------------------------- 2.1/11.9 MB 1.1 MB/s eta 0:00:10
#      ------- -------------------------------- 2.1/11.9 MB 1.1 MB/s eta 0:00:10
#      ------- -------------------------------- 2.1/11.9 MB 1.1 MB/s eta 0:00:10
#      ------- ------------------------------- 2.4/11.9 MB 958.5 kB/s eta 0:00:10
#      -------- ------------------------------ 2.6/11.9 MB 980.2 kB/s eta 0:00:10
#      --------- ----------------------------- 2.9/11.9 MB 958.5 kB/s eta 0:00:10
#      ---------- ---------------------------- 3.1/11.9 MB 986.9 kB/s eta 0:00:09
#      ----------- --------------------------- 3.4/11.9 MB 996.4 kB/s eta 0:00:09
#      ------------ --------------------------- 3.7/11.9 MB 1.0 MB/s eta 0:00:09
#      ------------- -------------------------- 3.9/11.9 MB 1.0 MB/s eta 0:00:08
#      -------------- ------------------------- 4.2/11.9 MB 1.0 MB/s eta 0:00:08
#      --------------- ------------------------ 4.5/11.9 MB 1.0 MB/s eta 0:00:08
#      --------------- ------------------------ 4.7/11.9 MB 1.1 MB/s eta 0:00:07
#      ---------------- ----------------------- 5.0/11.9 MB 1.1 MB/s eta 0:00:07
#      ----------------- ---------------------- 5.2/11.9 MB 1.1 MB/s eta 0:00:07
#      ------------------ --------------------- 5.5/11.9 MB 1.1 MB/s eta 0:00:06
#      -------------------- ------------------- 6.0/11.9 MB 1.1 MB/s eta 0:00:06
#      --------------------- ------------------ 6.3/11.9 MB 1.1 MB/s eta 0:00:05
#      ---------------------- ----------------- 6.6/11.9 MB 1.1 MB/s eta 0:00:05
#      ----------------------- ---------------- 7.1/11.9 MB 1.2 MB/s eta 0:00:05
#      ------------------------ --------------- 7.3/11.9 MB 1.2 MB/s eta 0:00:04
#      ------------------------- -------------- 7.6/11.9 MB 1.2 MB/s eta 0:00:04
#      -------------------------- ------------- 7.9/11.9 MB 1.2 MB/s eta 0:00:04
#      --------------------------- ------------ 8.1/11.9 MB 1.2 MB/s eta 0:00:04
#      ---------------------------- ----------- 8.4/11.9 MB 1.2 MB/s eta 0:00:03
#      ----------------------------- ---------- 8.7/11.9 MB 1.2 MB/s eta 0:00:03
#      ------------------------------ --------- 8.9/11.9 MB 1.2 MB/s eta 0:00:03
#      ------------------------------- -------- 9.4/11.9 MB 1.2 MB/s eta 0:00:02
#      -------------------------------- ------- 9.7/11.9 MB 1.2 MB/s eta 0:00:02
#      --------------------------------- ------ 10.0/11.9 MB 1.2 MB/s eta 0:00:02
#      ----------------------------------- ---- 10.5/11.9 MB 1.3 MB/s eta 0:00:02
#      ------------------------------------- -- 11.0/11.9 MB 1.3 MB/s eta 0:00:01
#      -------------------------------------- - 11.3/11.9 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  11.8/11.9 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 11.9/11.9 MB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (setup.py): started
#   Building wheel for mysql.connector (setup.py): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-win_amd64.whl size=247957 sha256=0e14cadeb61f6132c9eaee9583db1912c59c3e29e4598928d83eea690224400c
#   Stored in directory: c:\users\91991\appdata\local\pip\cache\wheels\03\17\fa\d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9
#   DEPRECATION: Building 'mysql.connector' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'mysql.connector'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\network.py:509, in MySQLTCPSocket.open_connection(self)
#     508     self.sock.settimeout(self._connection_timeout)
# --> 509     self.sock.connect(sockaddr)
#     510 except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection.py:206, in MySQLConnection._open_connection(self)
#     204 self._protocol = MySQLProtocol()
#     205 self._socket = self._get_connection()
# --> 206 self._socket.open_connection()
#     207 self._do_handshake()
#     208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\network.py:511, in MySQLTCPSocket.open_connection(self)
#     509     self.sock.connect(sockaddr)
#     510 except IOError as err:
# --> 511     raise errors.InterfaceError(
#     512         errno=2003, values=(self.get_address(), _strioerror(err)))
#     513 except Exception as err:
#     514     raise errors.OperationalError(str(err))
#
# InterfaceError: 2003: Can't connect to MySQL server on 'localhost:3306' (10061 No connection could be made because the target machine actively refused it)

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)

# %%
df
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
